# %%
# test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/DACON/commit/power-consumpsion-prediction
# Out:
# /content/drive/MyDrive/DACON/commit/power-consumpsion-prediction

# %%
! git config --global user.email 'hicg38@naver.com'
! git config --global user.name 'zefo38'

# %%
! git add
